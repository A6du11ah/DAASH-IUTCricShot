# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# ROOT_DIR = '/content/gdrive/My Drive/final'

# %%
# !pip install ultralytics opencv-python-headless

import torch
import cv2
import os
from google.colab import files

from ultralytics import YOLO

# %%
# # Load a model
# model = YOLO("yolov9c.pt")  # build a new model from scratch

# # Use the model
# results = model.train(data=os.path.join(ROOT_DIR, "final_config.yaml"), epochs=100)  # train the model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b125d36ec1ba> in <cell line: 2>()
#       1 # Load a model
# ----> 2 model = YOLO("yolov9c.pt")  # build a new model from scratch
#       3
#       4 # Use the model
#       5 results = model.train(data=os.path.join(ROOT_DIR, "final_config.yaml"), epochs=100)  # train the model
#
# NameError: name 'YOLO' is not defined

# %%
uploaded = files.upload()

# Move the uploaded video to a specific directory
os.makedirs('videos', exist_ok=True)
for file_name in uploaded.keys():
    os.rename(file_name, os.path.join('videos', file_name))
# Out:
#      <input type="file" id="files-2dd88218-b8b8-4673-832a-1966a2828e45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2dd88218-b8b8-4673-832a-1966a2828e45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
video_path = 'videos/4.mp4'
cap = cv2.VideoCapture(video_path)

# Get video writer initialized to save the output video
model = YOLO('/content/gdrive/MyDrive/Yolo v9c 100 Epoch train/weights/best.pt')
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('output.avi', cv2.VideoWriter_fourcc('M','J','P','G'), 30, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    # Draw bounding boxes on the frame
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
            conf = box.conf[0].cpu().numpy()
            cls = int(box.cls[0].cpu().numpy())
            label = f'{model.names[cls]} {conf:.2f}'
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Write the frame into the output file
    out.write(frame)

    # Optionally display the frame (comment out if not needed)
    #cv2.imshow('Frame', frame)
    #if cv2.waitKey(1) & 0xFF == ord('q'):
    #  break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

from google.colab import files
files.download('output.avi')
# Out:
# 0: 384x640 1 Batsman, 1 Bowler, 2 Fielders, 1 Umpire, 2 Keepers, 1 Non-strike-Batsman, 2034.1ms
# Speed: 16.3ms preprocess, 2034.1ms inference, 45.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 2 Fielders, 1 Umpire, 2 Keepers, 1 Non-strike-Batsman, 1657.9ms
# Speed: 5.5ms preprocess, 1657.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 2 Fielders, 1 Umpire, 2 Keepers, 1 Non-strike-Batsman, 3208.8ms
# Speed: 3.1ms preprocess, 3208.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 2 Fielders, 1 Umpire, 2 Keepers, 1 Non-strike-Batsman, 2866.9ms
# Speed: 2.5ms preprocess, 2866.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 2 Fielders, 1 Umpire, 1 Keeper, 1 Non-strike-Batsman, 1897.8ms
# ...

# %%
# #Download only the best model, careful that u trained more than once in same runtime, then following location
# #may change to ......./train{x}/.... where x is a positive integer more than 2

# files.download('/content/runs/detect/train/weights/best.pt')

# %%
# import shutil
# from google.colab import files

# #same goes as mentioned earlier, train number might change

# # Create a zip file of the folder
# shutil.make_archive('/content/train', 'zip', '/content/runs/detect/train')

# # Download the zip file
# files.download('/content/train.zip')

# %%
# #The following code is fro cropping and stretching

# import numpy as np

# video_path = 'videos/cover_0108.avi'
# cap = cv2.VideoCapture(video_path)


# model = YOLO('/content/runs/detect/train/weights/best.pt')

# output_size = (256, 256)
# out = cv2.VideoWriter('output2.avi', cv2.VideoWriter_fourcc('M','J','P','G'), 30, output_size)

# while cap.isOpened():
#     ret, frame = cap.read()
#     if not ret:
#         break

#     # Perform detection
#     results = model(frame)

#     # Flag to check if "Batsman" is detected
#     batsman_detected = False

#     for result in results:
#         boxes = result.boxes
#         for box in boxes:
#             x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
#             cls = int(box.cls[0].cpu().numpy())
#             label = model.names[cls]

#             if label == 'Batsman':  # Ensure the class name matches
#                 # Crop the frame to the bounding box
#                 cropped_frame = frame[y1:y2, x1:x2]

#                 # Resize the cropped frame to 256x256
#                 resized_frame = cv2.resize(cropped_frame, output_size)

#                 # Write the resized frame into the output file
#                 out.write(resized_frame)

#                 # Set the flag
#                 batsman_detected = True
#                 break

#         if batsman_detected:
#             break
#         else:
#           continue

#     # Optionally display the frame (comment out if not needed)
#     # cv2.imshow('Frame', resized_frame)
#     # if cv2.waitKey(1) & 0xFF == ord('q'):
#     #     break

# # Release resources
# cap.release()
# out.release()
# cv2.destroyAllWindows()

# # Download the output file
# from google.colab import files
# files.download('output2.avi')
# Out:
# 0: 384x640 1 Batsman, 1 Bowler, 1 Umpire, 1 Non-strike-Batsman, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 1 Umpire, 1 Non-strike-Batsman, 31.5ms
# Speed: 1.9ms preprocess, 31.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 1 Umpire, 1 Non-strike-Batsman, 31.4ms
# Speed: 1.5ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 1 Umpire, 1 Non-strike-Batsman, 24.4ms
# Speed: 1.6ms preprocess, 24.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 1 Umpire, 1 Non-strike-Batsman, 22.7ms
# Speed: 1.5ms preprocess, 22.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Batsman, 1 Bowler, 1 Umpire, 1 Non-strike-Batsman, 23.1ms
# ...
